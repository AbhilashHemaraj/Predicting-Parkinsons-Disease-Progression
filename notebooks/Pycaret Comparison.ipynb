# %%
from pycaret.datasets import get_data
boston = get_data('boston')
from pycaret.regression import *
exp_name = setup(data = boston,  target = 'medv')
lr = create_model('lr')
# Out:
# <style  type="text/css" >
# #T_2cc01_row10_col0,#T_2cc01_row10_col1,#T_2cc01_row10_col2,#T_2cc01_row10_col3,#T_2cc01_row10_col4,#T_2cc01_row10_col5{
#             background:  yellow;
#         }</style><table id="T_2cc01_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MAE</th>        <th class="col_heading level0 col1" >MSE</th>        <th class="col_heading level0 col2" >RMSE</th>        <th class="col_heading level0 col3" >R2</th>        <th class="col_heading level0 col4" >RMSLE</th>        <th class="col_heading level0 col5" >MAPE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_2cc01_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_2cc01_row0_col0" class="data row0 col0" >3.6343</td>
#                         <td id="T_2cc01_row0_col1" class="data row0 col1" >26.3938</td>
# ...

# %%
boston = get_data('boston')
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#     black  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
import pandas as pd
df = pd.read_csv("parkinsons_updrs.csv")

# %%
df
# Out:
#       subject  age  sex  test_time  motor_UPDRS  total_UPDRS  Jitter(%)  \
# 0           1   72    0     5.6431       28.199       34.398    0.00662
# 1           1   72    0    12.6660       28.447       34.894    0.00300
# 2           1   72    0    19.6810       28.695       35.389    0.00481
# 3           1   72    0    25.6470       28.905       35.810    0.00528
# 4           1   72    0    33.6420       29.187       36.375    0.00335
# ...       ...  ...  ...        ...          ...          ...        ...
# 5870       42   61    0   142.7900       22.485       33.485    0.00406
# 5871       42   61    0   149.8400       21.988       32.988    0.00297
# 5872       42   61    0   156.8200       21.495       32.495    0.00349
# 5873       42   61    0   163.7300       21.007       32.007    0.00281
# 5874       42   61    0   170.7300       20.513       31.513    0.00282
#
#       Jitter(Abs)  Jitter:RAP  Jitter:PPQ5  ...  Shimmer(dB)  Shimmer:APQ3  \
# ...

# %%
from pycaret.regression import *
exp_name = setup(data = df, ignore_features = ['total_UPDRS'],  target = 'motor_UPDRS')
# Out:
# <style  type="text/css" >
# #T_8b225_row42_col1{
#             background-color:  lightgreen;
#         }</style><table id="T_8b225_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8b225_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_8b225_row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_8b225_row0_col1" class="data row0 col1" >1622</td>
#             </tr>
#             <tr>
#                         <th id="T_8b225_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_8b225_row1_col0" class="data row1 col0" >Target</td>
#                         <td id="T_8b225_row1_col1" class="data row1 col1" >motor_UPDRS</td>
#             </tr>
#             <tr>
# ...

# %%
best = compare_models(exclude = ['ransac'])
# Out:
# <style  type="text/css" >
#     #T_53528_ th {
#           text-align: left;
# ...

# %%
df.columns
from pycaret.regression import *

# %%
exp_pca = setup(data = df, ignore_features = ['total_UPDRS'],  target = 'motor_UPDRS', pca = True, pca_components = 10)
# Out:
# <style  type="text/css" >
# #T_b06cd_row31_col1,#T_b06cd_row42_col1{
#             background-color:  lightgreen;
#         }</style><table id="T_b06cd_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b06cd_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_b06cd_row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_b06cd_row0_col1" class="data row0 col1" >5294</td>
#             </tr>
#             <tr>
#                         <th id="T_b06cd_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_b06cd_row1_col0" class="data row1 col0" >Target</td>
#                         <td id="T_b06cd_row1_col1" class="data row1 col1" >motor_UPDRS</td>
#             </tr>
# ...

# %%
best_pca = compare_models(exclude = ['ransac'])
# Out:
# <style  type="text/css" >
#     #T_54ac6_ th {
#           text-align: left;
# ...
